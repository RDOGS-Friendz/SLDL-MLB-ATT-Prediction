# %% [markdown]
# # 5~10 MA baseline

# %%
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# %%
data_test = pd.read_csv('../../statistical-learning/new_model_with_lle/testset_w_lle.csv')
data_test.head()
# Out:
#    attendance  is_federal_holiday                     venue  on_grass  \
# 0       35112                   0             Wrigley Field         1
# 1       28459                   0          Kauffman Stadium         1
# 2       46256                   0         Busch Stadium III         1
# 3       44723                   0  Angel Stadium of Anaheim         1
# 4       35508                   0               Chase Field         0
#
#    temperature  wind_speed team1_name  team1_pre_win  team1_pre_loss  \
# 0    -2.786672    1.292848        MIL       -1.62645       -1.654514
# 1    -2.503546    1.688830        CLE       -1.62645       -1.654514
# 2    -2.220421    2.480794        PIT       -1.62645       -1.654514
# 3     1.837706   -0.291081        HOU       -1.62645       -1.654514
# 4     1.837706   -0.291081        SDP       -1.62645       -1.654514
#
#    team1_pre_win_pct  ...  start_hour start_hour_label_afternoon  \
# ...

# %%
y_test = data_test['attendance'].to_numpy()
y_pred = data_test['previous_5_to_10MA'].to_numpy()

# %%
print("Test MSE:", mean_squared_error(y_test, y_pred))
print("Test RMSE:", mean_squared_error(y_test, y_pred, squared=False))
print("Test MAE:", mean_absolute_error(y_test, y_pred))
print("Test MAPE:", mean_absolute_percentage_error(y_test, y_pred))
# Out:
# Test MSE: 72263690.8802977
# Test RMSE: 8500.805307751596
# Test MAE: 6766.844407456573
# Test MAPE: 0.34921441042822426
